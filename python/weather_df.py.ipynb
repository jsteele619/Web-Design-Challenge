# %%
import pandas as pd
weather_df = pd.read_csv("main_df.csv")
weather_df
# Out:
#     Unnamed: 0                   City Country    Lat    Long  Max Temp  \
# 0            0                  Locri      IT  38.24   16.26     20.56
# 1            1            Tuktoyaktuk      CA  69.45 -133.04      2.00
# 2            2                  Badou      TG   7.58    0.60     21.40
# 3            3              Carnarvon      AU -24.87  113.63     23.00
# 4            4                Rikitea      PF -23.12 -134.97     22.62
# 5            5                  Kapaa      US  22.08 -159.32     28.00
# 6            6           Kampong Cham      KH  11.99  105.46     31.19
# 7            7                Mataura      NZ -46.19  168.86     16.67
# 8            8                  Bluff      NZ -46.60  168.33     16.67
# 9            9                  Sooke      CA  48.37 -123.73     15.00
# 10          10                 Cairns      AU -16.92  145.77     29.44
# 11          11                Fortuna      US  40.60 -124.16     13.33
# ...

# %%
weather_df.to_html(buf="weather_data.html", index=False)
